# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasstudy/deep-learning-keras-tf-tutorial/blob/master/House_Loan_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import require library
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load the dataset that is given to you
train_data = pd.read_csv('loan_data.csv')
print("Number of samples and feature:",train_data.shape)
# Out:
# Number of samples and feature: (307511, 122)

# %%
train_data.tail(5)
# Out:
#         SK_ID_CURR  ...  AMT_REQ_CREDIT_BUREAU_YEAR
# 307506      456251  ...                         NaN
# 307507      456252  ...                         NaN
# 307508      456253  ...                         1.0
# 307509      456254  ...                         0.0
# 307510      456255  ...                         1.0
#
# [5 rows x 122 columns]

# %%
count_miss_val = train_data.isnull().sum()
# Statistics of missing values ​​for each feature
count_miss_val.sort_values(reverse=True)
#train_data.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ab45ac226249> in <module>()
#       1 count_miss_val = train_data.isnull().sum()
#       2 # Statistics of missing values ​​for each feature
# ----> 3 count_miss_val.sort_values(reverse=True)
#       4 #train_data.dtypes
#
# TypeError: sort_values() got an unexpected keyword argument 'reverse'
